# %% [markdown]
# # **Scipy.Differntiate**
# ---
#
# >SciPy differentiate provides functions for performing finite difference numerical differentiation of black-box functions.
#
# ___

# %%
import scipy
import scipy.differentiate 

scipy.differentiate.derivative
# Out:
# <function scipy.differentiate._differentiate.derivative(f, x, *, args=(), tolerances=None, maxiter=10, order=8, initial_step=0.5, step_factor=2.0, step_direction=0, preserve_shape=False, callback=None)>
